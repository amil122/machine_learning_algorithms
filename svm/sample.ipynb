# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df['label'] = df['species'].replace({'species':'label'})

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#          label
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...

# %%
df = df.drop(columns = 'species', axis = 1)

# %%
df['label'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      label
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df[df['label']==1].head()
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, label]
# Index: []

# %%
import matplotlib.pyplot as plt

# %%
df0 = df[df['label']== 'setosa']
df0
# Out:
#     sepal_length  sepal_width  petal_length  petal_width   label
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df1 = df[df['label']== 'versicolor']
df2 = df[df['label']== 'virginica']

# %%
plt.scatter(x = df0['sepal_length'], y =df0['sepal_width'])
plt.scatter(x = df1['sepal_length'], y =df1['sepal_width'], color ='yellow')
plt.scatter(x = df2['sepal_length'], y =df2['sepal_width'], color ='red')

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['label']

# %%
x = df.drop(columns = 'label', axis =1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.svm import SVM

# %%
model = SVM(C = 5)
model.fit(x_train,y_train)
# Out:
# SVC(C=5)

# %%
model.predict(x_test)
# Out:
# array(['setosa', 'versicolor', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'versicolor', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'versicolor', 'setosa',
#        'virginica', 'virginica', 'setosa', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'virginica',
#        'versicolor'], dtype=object)

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Making predictions
pred = model.predict(x_test)
# Printing classification report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       1.00      1.00      1.00        14
#    virginica       1.00      1.00      1.00         7
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
# Printing confusion matrix and accuracy
print(confusion_matrix(y_test,pred))
print(accuracy_score(y_test,pred))
# Out:
# [[ 9  0  0]
#  [ 0 14  0]
#  [ 0  0  7]]
# 1.0
