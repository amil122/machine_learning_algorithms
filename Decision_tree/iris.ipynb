# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import random
from pprint import pprint
from sklearn.model_selection import train_test_split

# %%
 df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.rename(columns = {'species':'label'}, inplace = True)

# %%
df
df['label'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
x = df[['sepal_length','sepal_width','petal_length','petal_width']]
y = df['label']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 64            5.6          2.9           3.6          1.3
# 62            6.0          2.2           4.0          1.0
# 25            5.0          3.0           1.6          0.2
# 23            5.1          3.3           1.7          0.5
# 49            5.0          3.3           1.4          0.2
# ..            ...          ...           ...          ...
# 138           6.0          3.0           4.8          1.8
# 18            5.7          3.8           1.7          0.3
# 17            5.1          3.5           1.4          0.3
# 31            5.4          3.4           1.5          0.4
# 26            5.0          3.4           1.6          0.4
#
# [105 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 13            4.3          3.0           1.1          0.1
# 21            5.1          3.7           1.5          0.4
# 118           7.7          2.6           6.9          2.3
# 108           6.7          2.5           5.8          1.8
# 77            6.7          3.0           5.0          1.7
# 71            6.1          2.8           4.0          1.3
# 107           7.3          2.9           6.3          1.8
# 43            5.0          3.5           1.6          0.6
# 117           7.7          3.8           6.7          2.2
# 130           7.4          2.8           6.1          1.9
# 146           6.3          2.5           5.0          1.9
# 9             4.9          3.1           1.5          0.1
# 93            5.0          2.3           3.3          1.0
# 54            6.5          2.8           4.6          1.5
# 78            6.0          2.9           4.5          1.5
# 129           7.2          3.0           5.8          1.6
# 111           6.4          2.7           5.3          1.9
# 48            5.3          3.7           1.5          0.2
# 142           5.8          2.7           5.1          1.9
# 28            5.2          3.4           1.4          0.2
# 15            5.7          4.4           1.5          0.4
# 87            6.3          2.3           4.4          1.3
# 97            6.2          2.9           4.3          1.3
# 6             4.6          3.4           1.4          0.3
# 137           6.4          3.1           5.5          1.8
# 65            6.7          3.1           4.4          1.4
# 22            4.6          3.6           1.0          0.2
# 141           6.9          3.1           5.1          2.3
# 83            6.0          2.7           5.1          1.6
# 16            5.4          3.9           1.3          0.4
# 96            5.7          2.9           4.2          1.3
# 58            6.6          2.9           4.6          1.3
# 67            5.8          2.7           4.1          1.0
# 14            5.8          4.0           1.2          0.2
# 122           7.7          2.8           6.7          2.0
# 52            6.9          3.1           4.9          1.5
# 30            4.8          3.1           1.6          0.2
# 37            4.9          3.6           1.4          0.1
# 120           6.9          3.2           5.7          2.3
# 148           6.2          3.4           5.4          2.3
# 19            5.1          3.8           1.5          0.3
# 53            5.5          2.3           4.0          1.3
# 119           6.0          2.2           5.0          1.5
# 103           6.3          2.9           5.6          1.8
# 132           6.4          2.8           5.6          2.2

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_pred,y_test)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.93

# %% [markdown]
# from sklearn.tree import plot_tree
# plt.figure(figsize=(12,8))
# plot_tree(classifier, feature_names=['feature1', 'feature2'], class_names=['0', '1'], filled=True)
# plt.show()

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(12,8))
plot_tree(model, feature_names=['sepal_length','sepal_width','petal_length','petal_width'], class_names=['setosa', 'versicolor', 'virginica'], filled=True)
plt.show()

# %%
new_data = np.array([[5.1, 3.5, 1.4, 0.2],
                     [6.2, 3.4, 5.4, 2.3]])

# %%
model.predict(new_data)
# Out:
# C:\Users\amil\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['setosa', 'virginica'], dtype=object)
